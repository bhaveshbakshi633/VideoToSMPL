# %% [markdown]
# # VideoToSMPL — Notebook 04: WBC Simulation (placeholder)
#
# > **Status:** 🚧 placeholder — ships with `v0.2`.
#
# ## What this will do
#
# Given a retargeted G1 PKL from Notebook 02/03, roll it out in **MuJoCo under NVIDIA Groot WBC** — a whole-body controller trained to track reference motions while respecting balance, contact, and torque limits.
#
# ## Why a separate notebook
#
# - The WBC controller is large and has its own dependencies.
# - Tracks a reference rather than replays kinematically — outputs actuator torques, not joint positions.
# - Useful for validating motion feasibility before real-robot deployment.
#
# ## Contract (see [docs/WBC_INTEGRATION.md](https://bhaveshbakshi633.github.io/VideoToSMPL/docs/wbc-integration/))
#
# ```python
# class WBCController(Protocol):
#     def reset(self, motion: MotionData) -> None: ...
#     def step(self, obs: dict) -> np.ndarray: ...
#     def rollout(self, motion: MotionData, horizon: int) -> MotionData: ...
# ```
#
# The `core.wbc` package is the plugin point. The moment the Groot integration lands, this notebook becomes the end-to-end validator.
#
# ---
#
# _Follow the repo for the v0.2 tag to be notified when this ships._
